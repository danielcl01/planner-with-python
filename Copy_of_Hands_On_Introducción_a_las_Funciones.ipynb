# %% [markdown]
# <a href="https://colab.research.google.com/github/danielcl01/planner-with-python/blob/main/Copy_of_Hands_On_Introducci%C3%B3n_a_las_Funciones.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **HANDS - ON: INTRODUCCIÓN A LAS FUNCIONES**

# %% [markdown]
# Una vez visto la presentación ***Introducción a las funciones***, se proporciona el siguiente ***colab*** para que **el alumnado pueda practicar** haciendo uso del lenguaje de programación ***python***.
#
# De igual manera, se proporciona la **solución** de este notebook a través del siguiente [enlace](https://colab.research.google.com/drive/19WfNFwr8eu0YK3MGQh4RBczbKfbcqvgI?usp=sharing).

# %% [markdown]
# ## **FUNCIÓN INTEGRADA**

# %% [markdown]
# Una **función integrada** es un bloque de código reutilizable
#  predefinida en python que se utiliza para **realizar una tarea específica y están disponibles para su uso en cualquier momento** sin la necesidad de importar ningún módulo.

# %% [markdown]
# Una función integrada tiene la siguiente estructura:
#
# ```
# nombre_funcion(parametro1, parametro2, ...)
# ```

# %% [markdown]
# ### **EJEMPLO 1:**

# %% [markdown]
# Imprime una cadena de caracteres:

# %%
# difinir función

print('Hola mundo!')
# Out:
# Hola mundo!

# %% [markdown]
# ### **EJEMPLO 2:**

# %% [markdown]
# Devuelve la longitud de una lista:

# %%
# difinir función

len([1, 2, 3, 4, 5])
# Out:
# 5

# %% [markdown]
# ### **EJEMPLO 3:**

# %% [markdown]
# Devuelve una lista ordenada de elementos:

# %%
# difinir función

sorted([2, 4, 1, 5, 3])
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# ### **EJEMPLO 4:**

# %% [markdown]
# Redondea un número según un número determinado de decimales:

# %%
# difinir función

round(3.14159265, 4)
# Out:
# 3.1416

# %% [markdown]
# ### **EJEMPLO 5:**

# %% [markdown]
# Devuelve el valor mínimo en una lista:

# %%
# difinir función

min((3, 6, 7, 2, 10, 2))
# Out:
# 2

# %% [markdown]
# ## **FUNCIÓN DEFINIDA POR EL USUARIO**

# %% [markdown]
# Una **función definida por el usuario** es creada de manera personalizada para realizar tareas específicas y reutilizables en todo el programa. Este tipo de función se crea utilizando la palabra clave ` def` seguida del nombre de la función y los parámetros, si los hay.

# %% [markdown]
# Una función definida por el usuario tiene la siguiente estructura:
#
# ```
# def nombre_funcion(parametro1, parametro2, ...):
#     # Código que realiza una tarea específica
#
#     # Devolver un valor (opcional)
#     return valor
# ```

# %% [markdown]
# ### **EJEMPLO 1:**

# %% [markdown]
# Función que calcula el cuadrado de un número:

# %%
# difinir función

num_cuad = int(input('Ingresa un número: '))

def cuadrado(numero):
    return numero ** 2

cuadrado(num_cuad)
# Out:
# Ingresa un número: 4
# 16

# %% [markdown]
# ### **EJEMPLO 2:**

# %% [markdown]
# Función para verificar si un número es par o impar:

# %%
# difinir función

num_par = int(input('Ingresa un número: '))

def par(numero):
    if numero % 2 == 0:
        print('Par')
    else:
        print('Impar')

par(num_par)
# Out:
# Ingresa un número: 7
# Impar

# %% [markdown]
# ### **EJEMPLO 3:**

# %% [markdown]
# Función para calcular el factorial de un número:

# %%
# difinir función

num_fact = int(input('Ingresa un número: '))

def factorial(numero):
    if numero == 0:
        return 1
    else:
        return numero * factorial(numero - 1)

factorial(num_fact)
# Out:
# Ingresa un número: 5
# 120

# %% [markdown]
# ### **EJEMPLO 4:**

# %% [markdown]
# Función para unir dos listas en una sola lista:

# %%
# definir listas

lista_1 = [1, 2]
lista_2 = [3, 4, 5]

# %%
# difinir función

def unir(lista1, lista2):
    lista_unida = lista1 + lista2
    return lista_unida

unir(lista_1, lista_2)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# ### **EJEMPLO 5:**

# %% [markdown]
#  Función para buscar elementos dentro de un diccionario

# %%
# definir diccionario

diccionario = {'México': 'Toluca', 'Monterrey': 'Nuevo León', 'Jalisco': 'Guadalajara'}

# %%
# difinir función

clave = input('Ingrese una clave: ')

def buscar(diccionario, clave):
    return diccionario.get(clave)

buscar(diccionario, clave)
# Out:
# Ingrese una clave: México
# 'Toluca'

# %% [markdown]
# ## **CHALLENGE: AGENDA CON MENÚ CRUD**

# %% [markdown]
# Una vez visto el ***Hands - On: Introducción a las funciones***, se presentan la siguientes actividades para que el alumnado pueda repasar y reforzar lo aprendido dentro de la clase.

# %% [markdown]
# Dentro de la siguiente dinámica, **se utilizará el challenge del menú** para **separar por funciones los procesos del CRUD** donde **cada función será invocado dentro del ciclo donde se muestra el menú**, todo lo anterior haciendo uso de **Python**.
#
# Cada función deberá ejecutar cada operación del CRUD:
#
# *   **Ver agenda**
# *   **Crear contacto**
# *   **Consultar contacto**
# *   **Actualizar contacto**
# *   **Eliminar contacto**
# *   **Salir menú**

# %% [markdown]
# **IMPORTANTE:** Para su revisión, **es indispensable que los apartados anteriores se encuentren llenados con el código visto durante la sesión.**

# %% [markdown]
# ### **INSTRUCCIONES:**

# %% [markdown]
# **1. Crea la Agenda:** Construye la agenda con los registros utilizados en las prácticas anteriores.

# %%
# Definir agenda

planner = [
    {
        "fullname": "Francisco Hernandez",
        "email": "francisco@gmail.com",
        "cellphone": "+52 (826) 728 9907"
    },
    {
        "fullname": "Brenda Torres",
        "email": "brenda@gmail.com",
        "cellphone": "+52 (811) 708 0987"
    },
    {
        "fullname": "Pedro",
        "email": "pedro@gmail.com",
        "cellphone": "+52 (811) 708 0987"
    },
    {
        "fullname": "Alfredo Perez",
        "email": "alfredo@gmail.com",
        "cellphone": "823-118-3457"
    }
]

# Función para evaluar vacios
def is_empty(value):
  return value is None or value == ""

# %% [markdown]
# **2. Define una función que muestre las opciones del menú CRUD:**
#
#    * Crea una función que muestre el menú CRUD para la agenda con las opciones:
#
#    ```
#    Menú CRUD - Agenda:
#
#    1. Ver agenda
#    2. Crear contacto
#    3. Consultar contacto
#    4. Actualizar contacto
#    5. Eliminar contacto
#    6. Salir menú
#    ```

# %%
# Crear función menú opciones

def show_planner_menu():
  print('''
  Menú CRUD - Agenda:
  1. Ver agenda
  2. Crear contacto
  3. Consultar contacto
  4. Actualizar contacto
  5. Eliminar contacto
  6. Salir menú
  ''')

show_planner_menu()
# Out:
#   Menú CRUD - Agenda:
#   1. Ver agenda
#   2. Crear contacto
#   3. Consultar contacto
#   4. Actualizar contacto
#   5. Eliminar contacto
#   6. Salir menú

# %% [markdown]
# **3. Define una función que imprima todos los contactos de la agenda:**
#
#    * Crea una función que realice un ciclo for que recorra y muestre cada contacto de la agenda.
#    * Dentro del ciclo, muestra el número de contacto por cada iteración.

# %%
# Crear función mostrar agenda

# Obtiene el tamaño maximo de caracteres de una lista dado una clave
def get_max_size(_list, _key):
  newList = [len(item[_key]) for item in _list] if type(_list) == list else [0]
  return max(newList)

# Imprime todos los registros en formato de tabla
def see_all_records(_planner = planner):
  if (len(_planner) == 0):
    print('****Agenda vacía****')
    return

  headers = _planner[0].keys()
  headerRow = [{ key: key for key in headers }]
  maxSizes = {}
  headersStr = ''
  rows = ''

  # Crea la cabecera de la tabla en string
  # Agrega espacios calculados a la derecha
  for column in headers:
    maxSizes[column] = get_max_size(_planner + headerRow, column)
    headersStr += f'{column.capitalize()} {(maxSizes[column] - len(column)) * ' '}'

  # Crear las filas de la tabla en string
  # Agrega espacios calculados a la derecha
  for contact in _planner:
    for column in headers:
      rows += f'{contact[column]} {(maxSizes[column] - len(contact[column])) * ' '}'
    rows += '\n'

  print(headersStr)
  print(rows)

see_all_records()
# Out:
# Fullname            Email               Cellphone
# Francisco Hernandez francisco@gmail.com +52 (826) 728 9907
# Brenda Torres       brenda@gmail.com    +52 (811) 708 0987
# Pedro               pedro@gmail.com     +52 (811) 708 0987
# Alfredo Perez       alfredo@gmail.com   823-118-3457
# Daniel              jsijdsis            323

# %% [markdown]
# **5. Define una función para consultar un contacto de la agenda:**
#
#    * Crea una función que pida al usuario que ingrese el nombre del contacto a consultar.
#    * Realiza un ciclo for para la búsqueda del nombre dentro de la agenda.
#    * Sí el ciclo encuentra la búsqueda, entonces imprime el contacto encontrado.
#    * De lo contrario, entonces imprime "Contacto no encontrado".

# %%
# Crear función consultar contacto

def find_contact(fullname):
  contactFound = None
  index = 0
  for contact in planner:
    if contact['fullname'] == fullname:
      contactFound = contact
      break
    index += 1
  return {
      "contact": contactFound,
      "index": index
  }

def show_contact():
  fullname = input("Ingresa el nombre: ")
  contactFound = find_contact(fullname)['contact']

  if contactFound != None:
    see_all_records([contactFound])
  else:
    print('Contacto no encontrado')

show_contact()
# Out:
# Ingresa el nombre: Pedro
# Fullname Email           Cellphone
# Pedro    pedro@gmail.com +52 (811) 708 0987

# %% [markdown]
# **4. Define una función para crear un contacto de la agenda:**
#
#    * Crea una función que pida al usuario que ingrese el nombre, teléfono y correo para un contacto.
#    * Guarda estos datos en un diccionario llamado contacto.
#    * Imprime el mensaje "Contacto creado con éxito".

# %%
# Crear función crear contacto
def add_contact():
  fullname = input('Ingresa el nombre: ')
  email = input('Ingresa el email: ')
  cellphone = input('Ingresa el celular: ')
  contactFound = find_contact(fullname)

  if is_empty(fullname) or is_empty(email) or is_empty(cellphone):
    print('No se aceptan campos vacios')
    return

  if contactFound['contact'] == None:
    contact = {
        'fullname': fullname,
        "email": email,
        "cellphone": cellphone
    }
    planner.append(contact)
    print('Contacto creado con éxito')
  else:
    print(f'{fullname} ya existe dentro de la agenda, intenta con uno nuevo')

# %% [markdown]
# **6. Define una función para actualizar un contacto de la agenda:**
#
#  (Dada la complejidad y extensión de este punto se separará por partes).
#
#    * Crea una función que visualice un menú que contenga las siguientes opciones:
#
#    ```
#    Menú actualizar contacto:
#
#    1. Actualizar nombre
#    2. Actualizar teléfono
#    3. Actualziar correo
#    4. Salir del menú
#    ```

# %%
# Crear función menú para actualizar contacto
def show_update_menu():
  print('''
  Menú actualizar contacto:
  1. Actualizar nombre
  2. Actualizar teléfono
  3. Actualziar correo
  4. Salir del menú
  ''')

show_update_menu()
# Out:
#   Menú actualizar contacto:
#   1. Actualizar nombre
#   2. Actualizar teléfono
#   3. Actualziar correo
#   4. Salir del menú

# %% [markdown]
#    * Crea una función que realice un ciclo for para la búsqueda del nombre dentro de la agenda.
#    * Sí el ciclo encuentra la búsqueda, entonces retorna el contacto encontrado.
#    * De lo contrario, entonces retorna `None`.

# %%
# Crear función buscador contacto para actualizar contacto
contactFound = find_contact('Brenda Torres')['contact']
print(contactFound)
# Out:
# {'fullname': 'Brenda Torres', 'email': 'brenda@gmail.com', 'cellphone': '+52 (811) 708 0987'}

# %% [markdown]
#    * Crea una función para cada opción a escojer, modificando ya sea el nombre, el teléfono o el correo del contacto encontrado por nuevos registros.
#    * Por cada registro nuevo ingresado, imprime el contacto para visualizar los cambios.

# %%
# Crear función actualizar nombre para actualizar contacto
def update_contact_fullname(fullname, newFullname):
  if (is_empty(newFullname)):
    print('El nombre no puede ser vacio')
    return

  contactFound = find_contact(fullname)
  if contactFound['contact'] != None:
    print(f'({fullname}) actualizado por ({newFullname})')
    planner[contactFound['index']]['fullname'] = newFullname
  else:
    print("No fue posible actualizar el nombre")

# %%
# Crear función actualizar telefono para actualizar contacto
def update_contact_cellphone(fullname, newCellphone):
  if (is_empty(newCellphone)):
    print('El celular no puede ser vacio')
    return

  contactFound = find_contact(fullname)
  if contactFound['contact'] != None:
    cellphone = contactFound['contact']['cellphone']
    print(f'({cellphone}) actualizado por ({newCellphone})')
    planner[contactFound['index']]['cellphone'] = newCellphone
  else:
    print("No fue posible actualizar el celular")

# %%
# Crear función actualizar correo para actualizar contacto
def update_contact_email(fullname, newEmail):
  if (is_empty(newEmail)):
    print('El correo no puede ser vacio')
    return

  contactFound = find_contact(fullname)
  if contactFound['contact'] != None:
    email = contactFound['contact']['email']
    print(f'({email}) actualizado por ({newEmail})')
    planner[contactFound['index']]['email'] = newEmail
  else:
    print("No fue posible actualizar el correo")

# %% [markdown]
#    * Crea una función que integre las funciones creadas anteriormente a través de un ciclo while para un menú de actualizar un contacto.
#    * Pide al usuario que ingrese el nombre del contacto a actualizar.
#    * Solicita al usuario una opción mostrada en el menú, si el usuario no coloca la opción correcta, entonces muestra el mensaje "Opción no encontrada".
#    * Dada la opción escojida, ingresa a una función definida con anterioridad que corresponda a su operación a realizar.
#    * Define en la última opción un `break` para salir del menú.

# %%
# Crear función actualizar contacto
def show_update_contact():
  fullname = input("Ingresa el nombre del contacto: ")
  contactFound = find_contact(fullname)

  if contactFound['contact'] is not None:
    show_update_menu()
    optionSelected = int(input('Ingresa una opción valida: '))

    if (optionSelected > 0 and optionSelected < 5):
      while (optionSelected != 4):
        if (optionSelected == 1):
          newFullname = input('Ingresa el nuevo nombre: ')
          update_contact_fullname(fullname, newFullname)
        elif (optionSelected == 2):
          newCellphone = input('Ingresa el nuevo celular: ')
          update_contact_cellphone(fullname, newCellphone)
        elif (optionSelected == 3):
          newEmail = input('Ingresa el nuevo correo: ')
          update_contact_email(fullname, newEmail)
        show_update_menu()
        optionSelected = int(input('Ingresa una opción valida: '))
      print('Saliendo del menu actualizar...')
    else:
      print('Opción no encontrada, vuleve a intentar.')
  else:
    print("Contacto no encontrado")

show_update_contact()
# Out:
# Ingresa el nombre del contacto: Daniel
#
#   Menú actualizar contacto:
#   1. Actualizar nombre
#   2. Actualizar teléfono
#   3. Actualziar correo
#   4. Salir del menú
#
# Ingresa una opción valida: 4
# Saliendo del menu actualizar...

# %% [markdown]
# **7. Define una función para eliminar un contacto de la agenda:**
#
#    * Crea una función que pida al usuario que ingrese el nombre del contacto a eliminar.
#    * Realiza un ciclo for para la búsqueda del nombre dentro de la agenda.
#    * Sí el ciclo encuentra la búsqueda, entonces elimina el contacto encontrado.
#    * De lo contrario, entonces imprime "Contacto no encontrado".

# %%
# Crear función eliminar contacto
def delete_contact():
  fullname = input('Ingresa el nombre del contacto a eliminar: ')
  contactFound = find_contact(fullname)
  if contactFound['contact'] != None:
    planner.pop(contactFound['index'])
    print(f'Contacto "{fullname}" eliminado con exito')
  else:
    print(f'Contacto "{fullname}" no encontrado')

# %% [markdown]
# **8. Junta todas las funciones del menú CRUD dentro de una función:**
#
#    * Crea una función crear un menú a través de un ciclo while.
#    * Solicita al usuario una opción mostrada en el menú, si el usuario no coloca la opción correcta, entonces muestra el mensaje "Opción no encontrada".
#    * Dada la opción escojida, ingresa a una función definida con anterioridad que corresponda a su operación a realizar.
#    * Define en la última opción un `break` para salir del menú.

# %%
# Crear función menú agenda
def executePlannerCRUD():
  show_planner_menu()
  optionSelected = int(input("Ingresa una opción del menu: "))

  if (optionSelected > 0 and optionSelected < 7):
    while (optionSelected != 6):
      if (optionSelected == 1):
        see_all_records()
      elif (optionSelected == 2):
        add_contact()
      elif (optionSelected == 3):
        show_contact()
      elif (optionSelected == 4):
        show_update_contact()
      elif (optionSelected == 5):
        delete_contact()
      show_planner_menu()
      optionSelected = int(input('Ingresa una opción valida: '))
    print('Saliendo del menu actualizar...')
  else:
    print('Opción no encontrada, vuleve a intentar.')


executePlannerCRUD()
# Out:
#   Menú CRUD - Agenda:
#   1. Ver agenda
#   2. Crear contacto
#   3. Consultar contacto
#   4. Actualizar contacto
#   5. Eliminar contacto
#   6. Salir menú
#
# Ingresa una opción del menu: 1
# Fullname            Email               Cellphone
# Francisco Hernandez francisco@gmail.com +52 (826) 728 9907
# Brenda Torres       brenda@gmail.com    +52 (811) 708 0987
# Pedro               pedro@gmail.com     +52 (811) 708 0987
# Alfredo Perez       alfredo@gmail.com   823-118-3457
#
#
#   Menú CRUD - Agenda:
#   1. Ver agenda
#   2. Crear contacto
#   3. Consultar contacto
#   4. Actualizar contacto
#   5. Eliminar contacto
#   6. Salir menú
#
# Ingresa una opción valida: 2
# Ingresa el nombre: Daniel
# Ingresa el email: jsijdsis
# Ingresa el celular: 323
# Contacto creado con éxito
#
#   Menú CRUD - Agenda:
#   1. Ver agenda
#   2. Crear contacto
#   3. Consultar contacto
#   4. Actualizar contacto
#   5. Eliminar contacto
#   6. Salir menú
#
# Ingresa una opción valida: 3
# Ingresa el nombre: Daniel
# Fullname Email    Cellphone
# Daniel   jsijdsis 323
#
#
#   Menú CRUD - Agenda:
#   1. Ver agenda
#   2. Crear contacto
#   3. Consultar contacto
#   4. Actualizar contacto
#   5. Eliminar contacto
#   6. Salir menú
#
# Ingresa una opción valida: 6
# Saliendo del menu actualizar...
